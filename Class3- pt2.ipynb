# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(['A', 'A+', 'B', 'B+', 'C', 'C+'],
                   index = ['Excellent', 'Great', 'Very Good', 'Good', 'Okay', 'ok'],
                   columns = 'Grades'
                   )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_109/3200556406.py in <module>
#       1 df = pd.DataFrame(['A', 'A+', 'B', 'B+', 'C', 'C+'],
#       2                    index = ['Excellent', 'Great', 'Very Good', 'Good', 'Okay', 'ok'],
# ----> 3                    columns = 'Grades'
#       4                    )
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     486                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     487                 else:
# --> 488                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     489             else:
#     490                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ...
