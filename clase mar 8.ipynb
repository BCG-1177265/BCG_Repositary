# %%
import pandas as pd
import numpy as np

# %%
#pip install xlrd

# %%
#pip install openpyxl

# %%
#pip install seaborn

# %%
#pip install matplotlib

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
path = 'datasets/mic2.xlsx'
df = pd.read_excel(path,
                  engine = 'openpyxl'
                  )  
df.head(2)
# Out:
#                 Timestamp                           Name      Age   Sex  \
# 0 2021-09-24 11:41:37.540  Jobish Vallikavungal Devassia  31 - 40  Male
# 1 2021-09-24 11:44:42.933                         chikku  21 - 30  Male
#
#    Ocupation Monthly income   Price  Quality  Quantity  Availability  ...  \
# 0  Research         >40, 000      5        5         5             4  ...
# 1    student         <10,000      3        5         3             4  ...
#
#    Overal satisfaction  Consistency  Factor  Frowned           reason  \
# 0                    4            4   Taste       No              NaN
# 1                    4            4   Taste       No  Quantity issues
#
#      Popular  My favorite                     Kind Preference Recommend
# 0  Combo_VLM    Chocolate  More than one flavoured      agree     agree
# 1  Combo_VCS    Chocolate  More than one flavoured    neutral   neutral
#
# [2 rows x 26 columns]

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px

# %%
mpl.style.use('ggplot')

# %%
counts = df['Age'].value_counts()
counts
# Out:
# 21 - 30    37
# <=20        6
# 31 - 40     4
# 41 - 50     3
# Name: Age, dtype: int64

# %%
counts= counts.reindex(['<=20','21 - 30','31 - 40','41 - 50'])
counts
# Out:
# <=20        6
# 21 - 30    37
# 31 - 40     4
# 41 - 50     3
# Name: Age, dtype: int64

# %%
counts = counts.to_frame()
counts
# Out:
#          Age
# <=20       6
# 21 - 30   37
# 31 - 40    4
# 41 - 50    3

# %%
type(counts)
# Out:
# pandas.core.frame.DataFrame

# %%
counts['%'] = (counts.iloc[:, :]/counts.loc[:,'Age'].sum(axis = 0))*100

# %%
counts
# Out:
#          Age     %
# <=20       6  12.0
# 21 - 30   37  74.0
# 31 - 40    4   8.0
# 41 - 50    3   6.0

# %%
counts.columns
# Out:
# Index(['Age', '%'], dtype='object')

# %%
counts = counts.reset_index()
counts
# Out:
#      index  Age     %
# 0     <=20    6  12.0
# 1  21 - 30   37  74.0
# 2  31 - 40    4   8.0
# 3  41 - 50    3   6.0

# %%
counts = counts.rename({'index':'Age_group'},
                       axis = 1)
counts
# Out:
#   Age_group  Age     %
# 0      <=20    6  12.0
# 1   21 - 30   37  74.0
# 2   31 - 40    4   8.0
# 3   41 - 50    3   6.0

# %%
x = list(counts['Age_group'])
y = list(counts['Age'])

plt.subplot(1,2,1)
plt.rcParams['figure.figsize'] = (15,7)
plt.bar(x, y, width=0.7, color = 'lightblue')

plt.xlabel('Age Group', fontweight = 'regular', color = 'black', fontsize = 14, horizontalalignment = 'center')
plt.ylabel('Age', fontweight = 'regular', color = 'black', fontsize = 14, horizontalalignment = 'center')
plt.title('Number of respodents of diferent age groups', y = 1.01)

plt.subplot(1,2,2)
explode_list = [0.07, 0.05, 0.07, 0.03]
color_list = ['lightpink','skyblue','fuchsia','coral']

counts['Age'].plot(kind = 'pie',
                    figsize = (15, 6),
                    autopct = '%1.1f%%',
                    startangle = 90,
                    shadow = True,
                    labels = None,
                    pctdistance = 1.2,
                    explode = explode_list,
                    colors = color_list
                    )

plt.show()
