# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
type(3)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type('hi')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(')
# Out:
#   File "/tmp/ipykernel_61/1374600172.py", line 1
#     type(')
#            ^
# SyntaxError: EOL while scanning string literal

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(math.pi)
# Out:
# float

# %%
str
# Out:
# str

# %%
str
name = 'Barbara'
print(name)
# Out:
# Barbara

# %%
name2 = 'name222'

# %%
name2
# Out:
# 'name222'

# %%
name3 = name + name2
name3
# Out:
# 'Barbaraname222'

# %%
# %pwd
# Out:
# '/home/jovyan'

# %%
a_list = [2, 3, 4.0, 'a_name', True]

# %%
name2.find('e')
# Out:
# 3

# %%
a_list[2]
# Out:
# 4.0

# %%
listB = [2,3,4,5]

# %%
listB
# Out:
# [2, 3, 4, 5]

# %%
sum(listB)
# Out:
# 14

# %%
average = (sum(listB))/len(listB)
average
# Out:
# 3.5

# %%
x = 26
y = 7
if x < y :
    print('{} is less than {}'.format(x,y))
else:
    print(x,' is greater than ',y)
# Out:
# 26  is greater than  7

# %%
for i in a_list:
    print(i, '\t', type(i))
# Out:
# 2 	 <class 'int'>
# 3 	 <class 'int'>
# 4.0 	 <class 'float'>
# a_name 	 <class 'str'>
# True 	 <class 'bool'>

# %%
str_list = ['Done', 'Ctwo', 'Bthree', 'Afour']
str_list
# Out:
# ['Done', 'Ctwo', 'Bthree', 'Afour']

# %%
str_list.sort()
str_list
# Out:
# ['four', 'one', 'three', 'two']

# %%
str_list.sort()
str_list
# Out:
# ['Afour', 'Bthree', 'Ctwo', 'Done']

# %%
str_list[0:2]
# Out:
# ['Afour', 'Bthree']

# %%
str_list[0:4]
# Out:
# ['Afour', 'Bthree', 'Ctwo', 'Done']

# %%
str_list[-1]
# Out:
# 'Done'

# %%
str_list[-3:-1]
# Out:
# ['Bthree', 'Ctwo']

# %%
str_list[:-1]
# Out:
# ['Afour', 'Bthree', 'Ctwo']

# %%
import numpy as np

# %%
a = [1,2,3,4]
np.mean(a)
# Out:
# 2.5

# %%
a = np.dot([2j, 3j], [2,3j])
a
# Out:
# (-9+4j)

# %%
b = np.dot(3,4)
print(b)
type(b)
# Out:
# 12
# numpy.int64
